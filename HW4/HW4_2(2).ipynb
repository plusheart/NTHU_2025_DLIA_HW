# %% [markdown]
# <div align="center">
#
# ### Lab 4
#
# # National Tsing Hua University
#
# #### Spring 2025
#
# #### 11320IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 4: Predicting Stock Price with Deep Learning
#
# </div>

# %% [markdown]
# ### Introduction
#
# In this lab, we explore the application of time-series datasets using Long Short-Term Memory (LSTM) networks, a type of recurrent neural network, to predict stock prices. Specifically, we will use historical price data from Nvidia to forecast the stock's price for the next day based on the prices of the previous N days. This approach is particularly relevant given the volatile nature of stock markets and the increasing reliance on automated trading systems.
#
# ### Objectives
#
# - To understand the fundamentals of LSTM networks and their application in time-series forecasting.
# - To develop a predictive model that can accurately forecast Nvidia's stock price for the next day using historical data.
#
# ### Dataset
#
# The dataset for this lab is from the "Huge Stock Market Dataset" available on Kaggle. This dataset includes daily prices and volumes for all US stocks and ETFs, with a specific focus on Nvidia (NVDA). The dataset features include:
#
# - **Date**: The recorded data points.
# - **Open**: The price at which the stock first traded upon the opening of an exchange on a given trading day.
# - **High**: The highest price at which the stock traded during the trading day.
# - **Low**: The lowest price at which the stock traded during the trading day.
# - **Close**: The price of the stock at closing time.
# - **Volume**: The number of shares or contracts traded in a security or an entire market during a given period.
# - **OpenInt**: The total number of outstanding derivative contracts, like options or futures. [More details here](https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/discussion/121096)
#
# ### References
#
# - [Huge Stock Market Dataset](https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs) for the dataset used in this lab.

# %% [markdown]
# 訓練一個 LSTM 模型來預測 NVIDIA 股票的隔日最高價（High）

# %% [markdown]
# ## A. Checking and Preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/DeepLearning/hw4/nvda.us.txt')
df
# Out:
#             Date      Open      High       Low     Close    Volume  OpenInt
# 0     1999-01-22    1.6238    1.8092    1.4379    1.5215  18297633        0
# 1     1999-01-25    1.6423    1.6980    1.5215    1.6793   3445279        0
# 2     1999-01-26    1.6980    1.7350    1.5311    1.5494   2320993        0
# 3     1999-01-27    1.5586    1.5957    1.4660    1.5494   1662658        0
# 4     1999-01-28    1.5494    1.5586    1.5311    1.5401   1540110        0
# ...          ...       ...       ...       ...       ...       ...      ...
# 4728  2017-11-06  207.2000  209.9800  206.7000  209.6300   9731783        0
# 4729  2017-11-07  210.5500  212.9000  210.0560  212.0000  10671815        0
# 4730  2017-11-08  211.8500  212.0000  207.2400  209.1600  13033902        0
# 4731  2017-11-09  205.2700  206.3300  200.3700  205.3200  23895006        0
# 4732  2017-11-10  213.0800  218.6700  211.6300  216.1400  31300857        0
#
# [4733 rows x 7 columns]

# %%
# 繪製 High（每日最高價）折線圖作為初步觀察
plot = df.plot('Date', 'High', figsize=(15, 5))

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'OpenInt'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4733 entries, 0 to 4732
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     4733 non-null   object
#  1   Open     4733 non-null   float64
#  2   High     4733 non-null   float64
#  3   Low      4733 non-null   float64
#  4   Close    4733 non-null   float64
#  5   Volume   4733 non-null   int64
#  6   OpenInt  4733 non-null   int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 259.0+ KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume     0
# OpenInt    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (4733, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  4733.000000  4733.000000  4733.000000  4733.000000  4.733000e+03
# mean     20.796242    21.157332    20.420417    20.805404  1.615287e+07
# std      30.236284    30.615622    29.792958    30.263705  1.272446e+07
# min       1.298900     1.317500     1.233900     1.261900  0.000000e+00
# 25%       7.988300     8.247900     7.756400     7.978900  8.181100e+06
# 50%      12.963000    13.238000    12.721000    12.990000  1.390271e+07
# 75%      19.141000    19.418000    18.778000    19.106000  2.051602e+07
# max     213.080000   218.670000   211.630000   216.140000  2.496659e+08
#
#        OpenInt
# count   4733.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %% [markdown]
# #### Converting the DataFrame to a NumPy Array

# %%
# 將資料轉成時間序列格式，window size 為 10，step 為 15
def create_sequences(input_data, output_data, window_size, step):
    sequences = []
    labels = []
    for i in range(0, len(input_data) - window_size, step):
        sequences.append(input_data[i:(i + window_size)])
        labels.append(output_data[i + window_size])
    return np.array(sequences), np.array(labels)

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt

# Select features
features = df[['Open', 'High', 'Low', 'Close', 'Volume']]
labels = df['High'].shift(-1)  # Next day's high price as label

# window siez & step 在這!!!
X, y = create_sequences(features, labels, window_size=10, step=15)

print(f'Shape of data X: {X.shape}')
print(f'Shape of data y: {y.shape}')

# split the hold-out tests
ind = np.linspace(0, len(X)-1, num=int(len(X)*0.1), dtype=int) # 10% hold-out
x_test = X[ind]
y_test = y[ind]
all_ind = np.arange(len(X))
remains_ind = np.delete(all_ind, ind)

X = X[remains_ind]
y = y[remains_ind]

# shuffle dataset
ind = np.random.permutation(len(X))
X = X[ind]
y = y[ind]
split_point = int(X.shape[0]*0.8)

x_train = X[:split_point]
y_train = y[:split_point]
x_val = X[split_point:]
y_val = y[split_point:]

print(f'Shape of data x_train: {x_train.shape}')
print(f'Shape of data y_train: {y_train.shape}')
print(f'Shape of data x_val: {x_val.shape}')
print(f'Shape of data y_val: {y_val.shape}')
print(f'Shape of data x_test: {x_test.shape}')
print(f'Shape of data y_test: {y_test.shape}')

# Convert to PyTorch tensors
x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).float()

x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).float()

x_test = torch.from_numpy(x_test).float()
y_test = torch.from_numpy(y_test).float()

batch_size = 32

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)
test_dataset = TensorDataset(x_test, y_test)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f'Number of samples in training and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
# Out:
# Shape of data X: (315, 10, 5)
# Shape of data y: (315,)
# Shape of data x_train: (227, 10, 5)
# Shape of data y_train: (227,)
# Shape of data x_val: (57, 10, 5)
# Shape of data y_val: (57,)
# Shape of data x_test: (31, 10, 5)
# Shape of data y_test: (31,)
# Number of samples in training and validation are 227 and 57.

# %% [markdown]
# ## B. Defining Neural Networks

# %%
import torch.nn as nn

class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# ## C. Training the Neural Network

# %%
# Check your GPU status.
# !nvidia-smi
# Out:
# Thu May  1 05:00:50 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   48C    P0             26W /   70W |     328MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# 第三題: 加上 volume, normalize

# %%
# 將模型訓練封裝成函數以利重複使用
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from tqdm.auto import tqdm

def train_and_evaluate(window_size, step, scaling='none'):
    feature_cols = ['Open', 'High', 'Low', 'Close', 'Volume']
    raw_features = df[feature_cols]
    labels = df['High'].shift(-1).values  # 預測下一天的 High

    if 'Volume' in feature_cols and scaling == 'none':
        # 僅對 Volume 做 scaling，其餘欄位保留原始值
        feature_array = raw_features.copy()
        vol_scaler = StandardScaler()  # 或 MinMaxScaler()
        volume_scaled = vol_scaler.fit_transform(feature_array[['Volume']])
        feature_array['Volume'] = volume_scaled
        features = feature_array.values
    else:
        # 其他 scaling 選項
        if scaling == 'minmax':
            scaler = MinMaxScaler()
            features = scaler.fit_transform(raw_features)
        elif scaling == 'standard':
            scaler = StandardScaler()
            features = scaler.fit_transform(raw_features)
        else:  # no normalization
            features = raw_features.values

    # 後續流程照原本進行
    X, y = create_sequences(features, labels, window_size=window_size, step=step)

    X = X.astype(np.float32)
    y = y.astype(np.float32)

    # drop NA
    mask = ~np.isnan(y)
    X = X[mask]
    y = y[mask]

    # 分出 test
    ind = np.linspace(0, len(X)-1, num=int(len(X)*0.1), dtype=int)
    x_test = X[ind]
    y_test = y[ind]
    remains_ind = np.delete(np.arange(len(X)), ind)

    X = X[remains_ind]
    y = y[remains_ind]

    # shuffle + split train/val
    ind = np.random.permutation(len(X))
    X = X[ind]
    y = y[ind]
    split_point = int(X.shape[0]*0.8)
    x_train = X[:split_point]
    y_train = y[:split_point]
    x_val = X[split_point:]
    y_val = y[split_point:]

    # tensor 化
    x_train = torch.from_numpy(x_train).float().cuda()
    y_train = torch.from_numpy(y_train).float().cuda()
    x_val = torch.from_numpy(x_val).float().cuda()
    y_val = torch.from_numpy(y_val).float().cuda()
    x_test = torch.from_numpy(x_test).float().cuda()
    y_test = torch.from_numpy(y_test).float().cuda()

    # dataloader
    train_loader = DataLoader(TensorDataset(x_train, y_train), batch_size=32, shuffle=True)
    val_loader = DataLoader(TensorDataset(x_val, y_val), batch_size=32, shuffle=False)
    test_loader = DataLoader(TensorDataset(x_test, y_test), batch_size=32, shuffle=False)

    # 模型與訓練設定
    model = LSTMModel(input_dim=5, hidden_dim=500, num_layers=2, output_dim=1).cuda()
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0)
    criterion = nn.MSELoss()

    best_val_loss = float('inf')

    for epoch in range(epochs):
        model.train()
        total_loss = 0.0
        for features, labels in train_loader:
            outputs = model(features).squeeze(-1)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        scheduler.step()

        # 驗證
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for features, labels in val_loader:
                outputs = model(features).squeeze(-1)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
        avg_val_loss = val_loss / len(val_loader)
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss

    # 測試 MSE
    model.eval()
    test_loss = 0.0
    with torch.no_grad():
        for features, labels in test_loader:
            outputs = model(features).squeeze(-1)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
    avg_test_loss = test_loss / len(test_loader)

    return best_val_loss, avg_test_loss

# %%
# 將模型訓練封裝成函數以利重複使用
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from tqdm.auto import tqdm

def train_and_evaluate_all(window_size, step, scaling='none'):
    feature_cols = ['Open', 'High', 'Low', 'Close', 'Volume','OpenInt']
    raw_features = df[feature_cols]
    labels = df['High'].shift(-1).values  # 預測下一天的 High

    if 'Volume' in feature_cols and scaling == 'none':
        # 僅對 Volume 做 scaling，其餘欄位保留原始值
        feature_array = raw_features.copy()
        vol_scaler = StandardScaler()  # 或 MinMaxScaler()
        volume_scaled = vol_scaler.fit_transform(feature_array[['Volume']])
        feature_array['Volume'] = volume_scaled
        features = feature_array.values
    else:
        # 其他 scaling 選項
        if scaling == 'minmax':
            scaler = MinMaxScaler()
            features = scaler.fit_transform(raw_features)
        elif scaling == 'standard':
            scaler = StandardScaler()
            features = scaler.fit_transform(raw_features)
        else:  # no normalization
            features = raw_features.values

    # 後續流程照原本進行
    X, y = create_sequences(features, labels, window_size=window_size, step=step)

    X = X.astype(np.float32)
    y = y.astype(np.float32)

    # drop NA
    mask = ~np.isnan(y)
    X = X[mask]
    y = y[mask]

    # 分出 test
    ind = np.linspace(0, len(X)-1, num=int(len(X)*0.1), dtype=int)
    x_test = X[ind]
    y_test = y[ind]
    remains_ind = np.delete(np.arange(len(X)), ind)

    X = X[remains_ind]
    y = y[remains_ind]

    # shuffle + split train/val
    ind = np.random.permutation(len(X))
    X = X[ind]
    y = y[ind]
    split_point = int(X.shape[0]*0.8)
    x_train = X[:split_point]
    y_train = y[:split_point]
    x_val = X[split_point:]
    y_val = y[split_point:]

    # tensor 化
    x_train = torch.from_numpy(x_train).float().cuda()
    y_train = torch.from_numpy(y_train).float().cuda()
    x_val = torch.from_numpy(x_val).float().cuda()
    y_val = torch.from_numpy(y_val).float().cuda()
    x_test = torch.from_numpy(x_test).float().cuda()
    y_test = torch.from_numpy(y_test).float().cuda()

    # dataloader
    train_loader = DataLoader(TensorDataset(x_train, y_train), batch_size=32, shuffle=True)
    val_loader = DataLoader(TensorDataset(x_val, y_val), batch_size=32, shuffle=False)
    test_loader = DataLoader(TensorDataset(x_test, y_test), batch_size=32, shuffle=False)

    # 模型與訓練設定
    model = LSTMModel(input_dim=6, hidden_dim=500, num_layers=2, output_dim=1).cuda()
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0)
    criterion = nn.MSELoss()

    best_val_loss = float('inf')

    for epoch in range(epochs):
        model.train()
        total_loss = 0.0
        for features, labels in train_loader:
            outputs = model(features).squeeze(-1)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        scheduler.step()

        # 驗證
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for features, labels in val_loader:
                outputs = model(features).squeeze(-1)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
        avg_val_loss = val_loss / len(val_loader)
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss

    # 測試 MSE
    model.eval()
    test_loss = 0.0
    with torch.no_grad():
        for features, labels in test_loader:
            outputs = model(features).squeeze(-1)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
    avg_test_loss = test_loss / len(test_loader)

    return best_val_loss, avg_test_loss

# %%
# 測試不同 window size & step 組合
window_step_combos = [(5, 1), (1, 5), (15, 10), (10, 10), (10, 15) ,(30, 20), (20, 30)]
scaling_methods = ['none']

results = []

# %% [markdown]
# 加入volume, 進行scale

# %%
print("ALL")
for scaling in scaling_methods:
    print(f"\n=== Scaling method: {scaling.upper()} ===")
    for ws, st in window_step_combos:
        print(f"Training for window_size={ws}, step={st}")
        val_loss, test_loss = train_and_evaluate(ws, st, scaling=scaling)
        results.append((scaling, ws, st, val_loss, test_loss))
        print(f"--> Val Loss: {val_loss:.4f}, Test Loss: {test_loss:.4f}")
# Out:
# ALL
#
# === Scaling method: NONE ===
# Training for window_size=5, step=1
# --> Val Loss: 1.3731, Test Loss: 2.3530
# Training for window_size=1, step=5
# --> Val Loss: 17.3069, Test Loss: 40.6754
# Training for window_size=15, step=10
# --> Val Loss: 149.0805, Test Loss: 300.6922
# Training for window_size=10, step=10
# --> Val Loss: 35.7973, Test Loss: 288.2045
# Training for window_size=10, step=15
# --> Val Loss: 3.2522, Test Loss: 275.9183
# Training for window_size=30, step=20
# --> Val Loss: 32.1855, Test Loss: 991.6145
# Training for window_size=20, step=30
# --> Val Loss: 0.7343, Test Loss: 1456.9147

# %% [markdown]
# 加入全部特徵: volume 進行 scale

# %%
print("ALL!")
for scaling in scaling_methods:
    print(f"\n=== Scaling method: {scaling.upper()} ===")
    for ws, st in window_step_combos:
        print(f"Training for window_size={ws}, step={st}")
        val_loss, test_loss = train_and_evaluate_all(ws, st, scaling=scaling)
        results.append((scaling, ws, st, val_loss, test_loss))
        print(f"--> Val Loss: {val_loss:.4f}, Test Loss: {test_loss:.4f}")
# Out:
# ALL!
#
# === Scaling method: NONE ===
# Training for window_size=5, step=1
# --> Val Loss: 1.2607, Test Loss: 2.4357
# Training for window_size=1, step=5
# --> Val Loss: 8.3777, Test Loss: 37.2839
# Training for window_size=15, step=10
# --> Val Loss: 9.2242, Test Loss: 166.9445
# Training for window_size=10, step=10
# --> Val Loss: 114.4177, Test Loss: 224.6707
# Training for window_size=10, step=15
# --> Val Loss: 5.7419, Test Loss: 263.4539
# Training for window_size=30, step=20
# --> Val Loss: 107.6748, Test Loss: 658.6199
# Training for window_size=20, step=30
# --> Val Loss: 622.7682, Test Loss: 1298.0953

# %%
import pandas as pd

# 將結果轉成 DataFrame 表格
results_df = pd.DataFrame(results, columns=['Scaling', 'Window Size', 'Step Size', 'Val MSE', 'Test MSE'])

# 以 Excel 樣式格式化顯示，但不加高亮或標記
results_df.style.set_caption("All Results Comparison") \
                .format({'Val MSE': '{:.4f}', 'Test MSE': '{:.4f}'}) \
                .set_table_styles([{
                    'selector': 'th',
                    'props': [('background-color', '#f0f0f0'), ('font-weight', 'bold')]
                }])
# Out:
# <style type="text/css">
# #T_ea61d th {
#   background-color: #f0f0f0;
#   font-weight: bold;
# }
# </style>
# <table id="T_ea61d" class="dataframe">
#   <caption>All Results Comparison</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea61d_level0_col0" class="col_heading level0 col0" >Scaling</th>
#       <th id="T_ea61d_level0_col1" class="col_heading level0 col1" >Window Size</th>
#       <th id="T_ea61d_level0_col2" class="col_heading level0 col2" >Step Size</th>
#       <th id="T_ea61d_level0_col3" class="col_heading level0 col3" >Val MSE</th>
#       <th id="T_ea61d_level0_col4" class="col_heading level0 col4" >Test MSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea61d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea61d_row0_col0" class="data row0 col0" >none</td>
#       <td id="T_ea61d_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_ea61d_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_ea61d_row0_col3" class="data row0 col3" >843.6297</td>
#       <td id="T_ea61d_row0_col4" class="data row0 col4" >1202.8036</td>
#     </tr>
#     <tr>
#       <th id="T_ea61d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ea61d_row1_col0" class="data row1 col0" >none</td>
#       <td id="T_ea61d_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_ea61d_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_ea61d_row1_col3" class="data row1 col3" >699.8832</td>
#       <td id="T_ea61d_row1_col4" class="data row1 col4" >1193.0567</td>
#     </tr>
#     <tr>
#       <th id="T_ea61d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ea61d_row2_col0" class="data row2 col0" >none</td>
#       <td id="T_ea61d_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_ea61d_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_ea61d_row2_col3" class="data row2 col3" >624.5454</td>
#       <td id="T_ea61d_row2_col4" class="data row2 col4" >2043.1711</td>
#     </tr>
#     <tr>
#       <th id="T_ea61d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ea61d_row3_col0" class="data row3 col0" >none</td>
#       <td id="T_ea61d_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_ea61d_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_ea61d_row3_col3" class="data row3 col3" >801.3045</td>
#       <td id="T_ea61d_row3_col4" class="data row3 col4" >2067.2249</td>
#     </tr>
#     <tr>
#       <th id="T_ea61d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ea61d_row4_col0" class="data row4 col0" >none</td>
#       <td id="T_ea61d_row4_col1" class="data row4 col1" >10</td>
#       <td id="T_ea61d_row4_col2" class="data row4 col2" >15</td>
#       <td id="T_ea61d_row4_col3" class="data row4 col3" >1505.3035</td>
#       <td id="T_ea61d_row4_col4" class="data row4 col4" >1343.9171</td>
#     </tr>
#     <tr>
#       <th id="T_ea61d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ea61d_row5_col0" class="data row5 col0" >none</td>
#       <td id="T_ea61d_row5_col1" class="data row5 col1" >30</td>
#       <td id="T_ea61d_row5_col2" class="data row5 col2" >20</td>
#       <td id="T_ea61d_row5_col3" class="data row5 col3" >508.8568</td>
#       <td id="T_ea61d_row5_col4" class="data row5 col4" >1984.3075</td>
#     </tr>
#     <tr>
#       <th id="T_ea61d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ea61d_row6_col0" class="data row6 col0" >none</td>
#       <td id="T_ea61d_row6_col1" class="data row6 col1" >20</td>
#       <td id="T_ea61d_row6_col2" class="data row6 col2" >30</td>
#       <td id="T_ea61d_row6_col3" class="data row6 col3" >2295.9536</td>
#       <td id="T_ea61d_row6_col4" class="data row6 col4" >2480.0532</td>
#     </tr>
#   </tbody>
# </table>
